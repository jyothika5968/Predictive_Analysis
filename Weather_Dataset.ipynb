# %% [markdown]
# <a href="https://colab.research.google.com/github/jyothika5968/Predictive_Analysis/blob/main/Weather_Dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Predictive Analysis
import pandas as pd
df=pd.read_csv("/content/weather_forecast_data.csv",encoding='latin -1')
df.head()
# Out:
#    Temperature   Humidity  Wind_Speed  Cloud_Cover     Pressure     Rain
# 0    23.720338  89.592641    7.335604    50.501694  1032.378759     rain
# 1    27.879734  46.489704    5.952484     4.990053   992.614190  no rain
# 2    25.069084  83.072843    1.371992    14.855784  1007.231620  no rain
# 3    23.622080  74.367758    7.050551    67.255282   982.632013     rain
# 4    20.591370  96.858822    4.643921    47.676444   980.825142  no rain

# %%
df.tail()
# Out:
#       Temperature   Humidity  Wind_Speed  Cloud_Cover     Pressure     Rain
# 2495    21.791602  45.270902   11.807192    55.044682  1017.686181  no rain
# 2496    27.558479  46.481744   10.884915    39.715133  1008.590961  no rain
# 2497    28.108274  43.817178    2.897128    75.842952   999.119187  no rain
# 2498    14.789275  57.908105    2.374717     2.378743  1046.501875  no rain
# 2499    26.554356  97.101517   18.563084    81.357508  1001.729176  no rain

# %%
#avaerage Temperature
avg_temp=df['Temperature'].mean()
print(avg_temp)
# Out:
# 22.58172519939987

# %%
total_temp_usage = sum(df['Temperature'])
print(total_temp_usage)
# Out:
# 56454.31299849968

# %%
temp_increased=df['Temperature'][1]-df['Temperature']
print(temp_increased)
# Out:
# 0        4.159397
# 1        0.000000
# 2        2.810650
# 3        4.257655
# 4        7.288364
#           ...
# 2495     6.088133
# 2496     0.321256
# 2497    -0.228540
# 2498    13.090459
# 2499     1.325378
# Name: Temperature, Length: 2500, dtype: float64

# %%
Prediction = temp_increased + avg_temp
print(Prediction)
# Out:
# 0       26.741122
# 1       22.581725
# 2       25.392375
# 3       26.839380
# 4       29.870089
#           ...
# 2495    28.669858
# 2496    22.902981
# 2497    22.353185
# 2498    35.672184
# 2499    23.907104
# Name: Temperature, Length: 2500, dtype: float64

# %%
# to check rain will occur or not
if df['Rain'][2] =='rain':
  print("Rain will occur")
else:
  print("Rain will not occur")
# Out:
# Rain will not occur

# %%
#Visualization
import matplotlib.pyplot as plt
plt.plot(df['Temperature'])
plt.show()
